# %%
import pandas as pd

# %%
#read file

file = pd.read_csv('Volumes.csv', delim_whitespace=True)

# %%
file.head()
# Out:
#    Num             X             Y          Z  Real_Index  Real_Index_Top  \
# 0  1.0  395720.31806  7.159352e+06  990.57928         0.0             0.0
# 1  2.0  395846.38740  7.159426e+06  984.03906         1.0             1.0
# 2  3.0  395794.94946  7.159326e+06  985.98395         2.0             2.0
# 3  4.0  395721.03963  7.159402e+06  991.87573         3.0             3.0
# 4  5.0  394344.48197  7.157572e+06  996.64435         4.0             4.0
#
#    Real_Index_Bot_Thick  Oil_GRV_10_6    spill_Z      top_Z  OWC_depth  \
# 0                   0.0     104.44463  990.57928  949.99261  990.57928
# 1                   1.0      68.33327  984.03906  950.99329  984.03906
# 2                   2.0      62.89583  985.98395  947.91071  985.98395
# 3                   3.0      79.26017  991.87573  942.91193  991.87573
# 4                   4.0     128.36824  996.64435  944.85858  996.64435
#
#    OWC_area_10_6  nb_Connected  GRV_density__m_  Hc_column__m_  \
# ...

# %%
file.to_csv('Volumes_comma.csv', sep=',', index=False)
